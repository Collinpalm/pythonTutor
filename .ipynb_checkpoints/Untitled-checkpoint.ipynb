# %%
import numpy as np
import pandas as pd
import matplotlib
from pandas import read_csv



#read in data from csv using pandas
df = pd.read_csv('data.csv', header=None)
#save data to variable
data = df.to_numpy()

#save data to numpy array
narr = np.array(data).T

for i in range(0, 2):
    print(i)
    print("len: "+ str(np.size(narr[i])))
    print("Min: "+ str(np.min(narr[i])))
    print("Max: "+ str(np.max(narr[i])))
    print("Med: "+ str(np.median(narr[i])))
    print("Mean: "+ str(np.mean(narr[i])))
    print("Std: "+ str(np.std(narr[i])))
    

df.boxplot()
df.plot.scatter(x= 0, y=1)
# Out:
# 0
# len: 10836
# Min: 7.622587760902631e-05
# Max: 0.9998894422336768
# Med: 0.5024005930061334
# Mean: 0.5010763752650806
# Std: 0.28729528059586656
# 1
# len: 10836
# Min: 0.25525782022852284
# Max: 2.466480417266929
# Med: 1.2573267711591534
# Mean: 1.2570643193757078
# Std: 0.5767739470639723
# <AxesSubplot:xlabel='0', ylabel='1'>
